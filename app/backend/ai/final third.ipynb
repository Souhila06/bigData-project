# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score

# %%
df = pd.read_csv('./final_dataset.csv')

# %%
# Nombre de classes
n_classes = df['activityID'].nunique()
n_total = 1000000
# Taille de l'échantillon par classe
n_per_class = n_total // n_classes

# Échantillonnage uniforme
sample = df.groupby('activityID', group_keys=False).apply(
    lambda x: x.sample(n=min(len(x), n_per_class), random_state=42)
)

# Réinitialiser les indices
sample = sample.reset_index(drop=True)
# Out:
# /var/folders/xz/0tnfv35j1jjbznbfc7k0swh00000gn/T/ipykernel_3756/1609151039.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   sample = df.groupby('activityID', group_keys=False).apply(

# %%
sample['activityID'].value_counts()
# Out:
# activityID
# 0     52631
# 1     52631
# 19    52631
# 18    52631
# 17    52631
# 16    52631
# 13    52631
# 12    52631
# 11    52631
# 10    52631
# 9     52631
# 7     52631
# 6     52631
# 5     52631
# 4     52631
# 3     52631
# 2     52631
# 24    49360
# 20    46915
# Name: count, dtype: int64

# %%
X = sample.drop(columns=["activityID", "timestamp"])  # Supprimer les colonnes inutiles
y = sample["activityID"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_test[:5]
# Out:
#         heart_rate  IMU_hand_1  IMU_hand_2  IMU_hand_3  IMU_hand_4  \
# 790028        74.0     33.0625   -0.471641     6.16827    4.784650
# 340951       127.0     31.3125   -6.248670     4.67112    6.242670
# 415355       130.0     34.7500   -1.202980     7.64628   -0.273134
# 140258        79.0     35.0000   -1.804130     5.52362    7.884350
# 542453        97.0     34.5000   -1.676750     7.96842    5.607250
#
#         IMU_hand_5  IMU_hand_6  IMU_hand_7  IMU_hand_8  IMU_hand_9  ...  \
# 790028   -0.429769     6.08095    5.386960   -0.433044   -1.435590  ...
# 340951   -6.862460     4.07569    7.768760    0.421383    0.338674  ...
# 415355   -0.529832     8.20631    0.263248    0.214352    0.549867  ...
# 140258   -1.783260     5.62500    8.016880    0.512128    0.103416  ...
# 542453   -1.481780     7.82568    5.791940   -0.029716    0.011717  ...
#
#         IMU_ankle_8  IMU_ankle_9  IMU_ankle_10  IMU_ankle_11  IMU_ankle_12  \
# 790028     0.264466    -0.334172      0.170506     -43.47220       7.92984
# 340951     0.292395     0.028490      1.058610     -19.49650      43.73900
# 415355    -0.957080     1.385230      5.707040     -43.15400     -14.78870
# 140258     0.042430    -0.017714      0.005101     -35.81010       2.23863
# 542453     0.011285     0.019302      0.017970       5.04097       5.44570
#
#         IMU_ankle_13  IMU_ankle_14  IMU_ankle_15  IMU_ankle_16  IMU_ankle_17
# 790028       41.2428      0.080497      0.723002      0.132753      0.673175
# 340951       16.3232      0.502748      0.715163      0.261555      0.409116
# 415355       26.5197      0.124154      0.576958      0.596086      0.544414
# 140258       30.9226      0.044804     -0.762631      0.310686     -0.565562
# 542453      -21.6971      1.000000      0.000000      0.000000      0.000000
#
# [5 rows x 52 columns]

# %%
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', random_state=42, verbose=True)
svm_model.fit(X_train, y_train)
# Out:
# [LibSVM]..
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3388
# obj = -3341.741371, rho = -0.048353
# nSV = 3860, nBSV = 3778
# .....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 6185
# obj = -6129.508046, rho = -7.082853
# nSV = 7572, nBSV = 7498
# ..........
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 11720
# obj = -11248.962913, rho = -10.168933
# nSV = 14433, nBSV = 14335
# .................
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 19740
# obj = -21521.491418, rho = -4.403375
# nSV = 25799, nBSV = 25619
# ..........
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 11741
# obj = -9292.629019, rho = 4.423298
# nSV = 11819, nBSV = 11615
# ......
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 8012
# obj = -7358.490527, rho = -6.350421
# nSV = 8553, nBSV = 8437
# .................
# Warning: using -h 0 may be faster
# *.*.*
# optimization finished, #iter = 18790
# obj = -20146.912762, rho = -3.546150
# nSV = 25049, nBSV = 24863
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1442
# obj = -1328.747645, rho = -3.250322
# nSV = 1892, nBSV = 1854
# ...
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4260
# obj = -2947.920442, rho = -3.149214
# nSV = 3766, nBSV = 3692
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1373
# obj = -970.998756, rho = -2.462450
# nSV = 1336, nBSV = 1280
# ......................
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 24470
# obj = -27521.068448, rho = 0.873978
# nSV = 31565, nBSV = 31341
# ........................
# Warning: using -h 0 may be faster
# *...*
# optimization finished, #iter = 27117
# obj = -31233.252104, rho = 3.604671
# nSV = 35527, nBSV = 35290
# .................
# Warning: using -h 0 may be faster
# *..*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 20202
# obj = -22645.924668, rho = -6.616379
# nSV = 26332, nBSV = 26161
# ........
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *..*.*
# optimization finished, #iter = 10604
# obj = -8553.242893, rho = -8.357830
# nSV = 10435, nBSV = 10330
# .........
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 10086
# obj = -8215.071199, rho = -9.733629
# nSV = 10542, nBSV = 10425
# .................
# Warning: using -h 0 may be faster
# *...*
# optimization finished, #iter = 20659
# obj = -21105.035347, rho = -1.248131
# nSV = 25901, nBSV = 25684
# .......
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 8245
# obj = -7251.745881, rho = 1.849308
# nSV = 9155, nBSV = 8992
# ......
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 8216
# obj = -6829.311214, rho = 0.451948
# nSV = 8737, nBSV = 8570
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1390
# obj = -739.273758, rho = -3.400666
# nSV = 1183, nBSV = 1121
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1230
# obj = -591.344704, rho = -1.114378
# nSV = 1042, nBSV = 996
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1694
# obj = -897.962535, rho = -0.089496
# nSV = 1445, nBSV = 1380
# *
# optimization finished, #iter = 753
# obj = -318.224143, rho = -0.420330
# nSV = 600, nBSV = 530
# *
# optimization finished, #iter = 465
# obj = -162.648334, rho = -1.032072
# nSV = 310, nBSV = 279
# *
# optimization finished, #iter = 899
# obj = -379.311111, rho = -1.640050
# nSV = 683, nBSV = 627
# *
# optimization finished, #iter = 518
# obj = -134.296755, rho = -0.914439
# nSV = 259, nBSV = 223
# *
# optimization finished, #iter = 918
# obj = -482.290698, rho = -3.908480
# nSV = 822, nBSV = 784
# *
# optimization finished, #iter = 341
# obj = -89.030486, rho = -1.259082
# nSV = 184, nBSV = 148
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1883
# obj = -1245.155705, rho = 1.775784
# nSV = 1874, nBSV = 1815
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1947
# obj = -1178.506505, rho = 1.822527
# nSV = 1858, nBSV = 1782
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1725
# obj = -1128.459337, rho = -2.596036
# nSV = 1743, nBSV = 1674
# *.*
# optimization finished, #iter = 1156
# obj = -486.083538, rho = -2.060518
# nSV = 864, nBSV = 814
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1233
# obj = -476.725902, rho = -2.395517
# nSV = 884, nBSV = 826
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 2605
# obj = -1592.973314, rho = -0.983337
# nSV = 2314, nBSV = 2225
# *
# optimization finished, #iter = 607
# obj = -122.726878, rho = 0.253301
# nSV = 272, nBSV = 197
# *
# optimization finished, #iter = 535
# obj = -46.693940, rho = 0.428064
# nSV = 145, nBSV = 65
# .....
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 6494
# obj = -5723.754071, rho = -0.417181
# nSV = 7277, nBSV = 7208
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1818
# obj = -1096.062879, rho = 0.761543
# nSV = 1565, nBSV = 1490
# *
# optimization finished, #iter = 888
# obj = -438.119409, rho = 0.727592
# nSV = 776, nBSV = 719
# *
# optimization finished, #iter = 514
# obj = -320.524786, rho = -0.140209
# nSV = 542, nBSV = 514
# *.*
# optimization finished, #iter = 1202
# obj = -716.902565, rho = 0.083274
# nSV = 1223, nBSV = 1164
# *
# optimization finished, #iter = 765
# obj = -265.480152, rho = -2.230697
# nSV = 487, nBSV = 440
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1400
# obj = -861.123577, rho = 1.712759
# nSV = 1428, nBSV = 1383
# *
# optimization finished, #iter = 294
# obj = -83.501801, rho = 0.525354
# nSV = 171, nBSV = 143
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1956
# obj = -1405.894250, rho = 5.878532
# nSV = 2103, nBSV = 2038
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2302
# obj = -1657.852189, rho = 4.650837
# nSV = 2383, nBSV = 2313
# ....
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4990
# obj = -4636.746456, rho = 5.470119
# nSV = 6000, nBSV = 5930
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 2640
# obj = -2194.068736, rho = -1.563685
# nSV = 3173, nBSV = 3118
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1692
# obj = -795.834655, rho = -1.250496
# nSV = 1423, nBSV = 1363
# ....
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 5716
# obj = -4381.304459, rho = 7.244104
# nSV = 6350, nBSV = 6273
# *
# optimization finished, #iter = 538
# obj = -222.019574, rho = 1.981154
# nSV = 413, nBSV = 370
# *
# optimization finished, #iter = 379
# obj = -72.276551, rho = 1.014576
# nSV = 165, nBSV = 121
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3189
# obj = -2309.771939, rho = 0.870628
# nSV = 3516, nBSV = 3447
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1452
# obj = -804.225114, rho = 0.467359
# nSV = 1308, nBSV = 1240
# *
# optimization finished, #iter = 499
# obj = -199.512701, rho = -1.280611
# nSV = 374, nBSV = 340
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1820
# obj = -1066.715084, rho = -1.151655
# nSV = 1725, nBSV = 1663
# *
# optimization finished, #iter = 655
# obj = -231.135614, rho = -2.673218
# nSV = 444, nBSV = 404
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2109
# obj = -1245.582078, rho = 0.772590
# nSV = 2069, nBSV = 2018
# *
# optimization finished, #iter = 303
# obj = -107.328172, rho = 0.308909
# nSV = 205, nBSV = 180
# ..
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3842
# obj = -2381.946333, rho = 6.240098
# nSV = 3790, nBSV = 3705
# ...
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4310
# obj = -3397.920047, rho = 8.594872
# nSV = 5025, nBSV = 4937
# .....
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 5981
# obj = -6339.685203, rho = 5.473238
# nSV = 8166, nBSV = 8079
# ......
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 7601
# obj = -6325.823254, rho = 1.226796
# nSV = 8102, nBSV = 8032
# ...
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3510
# obj = -2417.578211, rho = -0.917502
# nSV = 3668, nBSV = 3596
# ......
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 7724
# obj = -6606.703067, rho = 7.327096
# nSV = 9563, nBSV = 9461
# *
# optimization finished, #iter = 660
# obj = -171.150588, rho = 0.242453
# nSV = 356, nBSV = 286
# *
# optimization finished, #iter = 822
# obj = -77.642495, rho = 0.205063
# nSV = 214, nBSV = 116
# .....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 6537
# obj = -4228.356869, rho = 4.413996
# nSV = 6197, nBSV = 6034
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3452
# obj = -2710.193207, rho = 0.594581
# nSV = 3821, nBSV = 3733
# ...........
# Warning: using -h 0 may be faster
# *..*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 13653
# obj = -13821.555709, rho = 2.813596
# nSV = 17271, nBSV = 17111
# *
# optimization finished, #iter = 567
# obj = -251.988283, rho = -1.192858
# nSV = 448, nBSV = 408
# *
# optimization finished, #iter = 961
# obj = -591.093345, rho = -0.101010
# nSV = 945, nBSV = 900
# *
# optimization finished, #iter = 435
# obj = -203.646935, rho = -0.270342
# nSV = 365, nBSV = 327
# .............
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 15191
# obj = -15491.730809, rho = 6.240704
# nSV = 19848, nBSV = 19670
# ............
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 14589
# obj = -14421.693168, rho = 9.320171
# nSV = 18636, nBSV = 18445
# ......
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 7839
# obj = -6975.707085, rho = 0.711181
# nSV = 9783, nBSV = 9672
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2269
# obj = -1757.087856, rho = -0.334499
# nSV = 2518, nBSV = 2448
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2319
# obj = -1434.343186, rho = -0.765560
# nSV = 2240, nBSV = 2165
# ....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 5924
# obj = -4115.407597, rho = 1.704441
# nSV = 5952, nBSV = 5807
# ...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4033
# obj = -1605.687143, rho = 1.518053
# nSV = 2894, nBSV = 2758
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2291
# obj = -783.654957, rho = 1.822513
# nSV = 1405, nBSV = 1292
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3134
# obj = -2250.279361, rho = -6.052497
# nSV = 3115, nBSV = 3015
# .........
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 10948
# obj = -7352.693724, rho = -6.994953
# nSV = 10657, nBSV = 10450
# *
# optimization finished, #iter = 410
# obj = -113.277065, rho = -0.855249
# nSV = 242, nBSV = 196
# *
# optimization finished, #iter = 642
# obj = -418.905908, rho = -0.225346
# nSV = 722, nBSV = 675
# *
# optimization finished, #iter = 423
# obj = -124.289123, rho = -1.114296
# nSV = 245, nBSV = 196
# ......
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 8431
# obj = -5542.603446, rho = -3.221314
# nSV = 8157, nBSV = 7963
# .......
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 8972
# obj = -5497.476775, rho = -1.524190
# nSV = 8209, nBSV = 8002
# ...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4305
# obj = -2445.372173, rho = -3.376584
# nSV = 3755, nBSV = 3642
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1343
# obj = -844.130918, rho = -1.863940
# nSV = 1387, nBSV = 1331
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1427
# obj = -652.032579, rho = -2.540298
# nSV = 1143, nBSV = 1066
# ...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4259
# obj = -2238.487115, rho = -0.939114
# nSV = 3422, nBSV = 3274
# .........
# Warning: using -h 0 may be faster
# *...*.*
# optimization finished, #iter = 12875
# obj = -7134.141062, rho = 1.344272
# nSV = 10610, nBSV = 10197
# .......
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 9734
# obj = -5569.617403, rho = -0.148356
# nSV = 8557, nBSV = 8262
# ....
# Warning: using -h 0 may be faster
# *.*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 5767
# obj = -4081.676268, rho = 1.930570
# nSV = 5438, nBSV = 5332
# *
# optimization finished, #iter = 385
# obj = -141.519730, rho = -0.050222
# nSV = 264, nBSV = 232
# *
# optimization finished, #iter = 543
# obj = -291.525772, rho = 0.282289
# nSV = 484, nBSV = 451
# *
# optimization finished, #iter = 273
# obj = -96.330752, rho = 0.029310
# nSV = 183, nBSV = 155
# ...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4684
# obj = -3642.250215, rho = 6.448932
# nSV = 4952, nBSV = 4849
# ....
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 5797
# obj = -4991.078036, rho = 10.088737
# nSV = 6786, nBSV = 6675
# ....
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4871
# obj = -3888.714039, rho = 3.941700
# nSV = 5476, nBSV = 5380
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1296
# obj = -1101.165089, rho = 2.451054
# nSV = 1707, nBSV = 1672
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1210
# obj = -646.046899, rho = 0.299858
# nSV = 1069, nBSV = 1016
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3518
# obj = -2219.965713, rho = 6.117500
# nSV = 3506, nBSV = 3402
# ..
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3074
# obj = -2198.124073, rho = 5.803032
# nSV = 3321, nBSV = 3233
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2346
# obj = -1600.756853, rho = 2.723552
# nSV = 2470, nBSV = 2377
# *
# optimization finished, #iter = 665
# obj = -294.856277, rho = -0.550596
# nSV = 531, nBSV = 498
# *
# optimization finished, #iter = 951
# obj = -445.798457, rho = 0.664769
# nSV = 785, nBSV = 732
# *
# optimization finished, #iter = 478
# obj = -246.724256, rho = 0.270158
# nSV = 426, nBSV = 390
# ..........
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 12156
# obj = -11185.654394, rho = 4.627753
# nSV = 15334, nBSV = 15144
# .........
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 11751
# obj = -9596.586663, rho = 6.616876
# nSV = 13373, nBSV = 13161
# .....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 6033
# obj = -4804.258043, rho = 0.378417
# nSV = 6921, nBSV = 6795
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2160
# obj = -1556.736475, rho = 1.233551
# nSV = 2420, nBSV = 2360
# ..
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3175
# obj = -1590.376554, rho = -0.546951
# nSV = 2502, nBSV = 2415
# ....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 5279
# obj = -3653.323957, rho = 1.814414
# nSV = 5385, nBSV = 5264
# ...
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 4734
# obj = -2635.666128, rho = 4.436552
# nSV = 4173, nBSV = 4025
# ....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 5754
# obj = -3962.410259, rho = 3.545609
# nSV = 6033, nBSV = 5876
# *
# optimization finished, #iter = 233
# obj = -69.788898, rho = -1.449103
# nSV = 140, nBSV = 109
# *
# optimization finished, #iter = 178
# obj = -25.619989, rho = -0.238286
# nSV = 69, nBSV = 42
# *
# optimization finished, #iter = 757
# obj = -374.908908, rho = 2.986363
# nSV = 642, nBSV = 589
# *
# optimization finished, #iter = 661
# obj = -315.213108, rho = 1.007592
# nSV = 561, nBSV = 516
# *
# optimization finished, #iter = 944
# obj = -430.286035, rho = -1.674942
# nSV = 720, nBSV = 674
# *
# optimization finished, #iter = 535
# obj = -160.174406, rho = -0.722102
# nSV = 304, nBSV = 268
# *
# optimization finished, #iter = 620
# obj = -305.351803, rho = -2.855318
# nSV = 515, nBSV = 479
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1313
# obj = -946.200622, rho = -0.043258
# nSV = 1406, nBSV = 1356
# *
# optimization finished, #iter = 501
# obj = -73.770962, rho = 0.158149
# nSV = 193, nBSV = 115
# *
# optimization finished, #iter = 545
# obj = -55.378900, rho = 0.604446
# nSV = 149, nBSV = 87
# *
# optimization finished, #iter = 165
# obj = -65.069712, rho = 0.882826
# nSV = 128, nBSV = 110
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1550
# obj = -733.568600, rho = 3.070173
# nSV = 1172, nBSV = 1117
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1519
# obj = -984.928191, rho = 2.221160
# nSV = 1575, nBSV = 1513
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1906
# obj = -1104.913708, rho = 1.570802
# nSV = 1778, nBSV = 1724
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2072
# obj = -1102.267443, rho = -0.741666
# nSV = 1855, nBSV = 1798
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1494
# obj = -720.159941, rho = 1.173018
# nSV = 1290, nBSV = 1236
# ...
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 3751
# obj = -2481.228543, rho = 1.834341
# nSV = 3713, nBSV = 3641
# *
# optimization finished, #iter = 362
# obj = -103.462989, rho = 2.971592
# nSV = 211, nBSV = 173
# *
# optimization finished, #iter = 266
# obj = -39.674139, rho = 1.032283
# nSV = 99, nBSV = 61
# *
# optimization finished, #iter = 449
# obj = -211.523050, rho = 0.402582
# nSV = 375, nBSV = 334
# *
# optimization finished, #iter = 892
# obj = -516.359717, rho = 2.069549
# nSV = 843, nBSV = 797
# *
# optimization finished, #iter = 598
# obj = -272.606703, rho = 0.604359
# nSV = 473, nBSV = 427
# *
# optimization finished, #iter = 311
# obj = -134.830531, rho = -0.624378
# nSV = 247, nBSV = 222
# *
# optimization finished, #iter = 401
# obj = -113.223798, rho = 0.285055
# nSV = 234, nBSV = 194
# *
# optimization finished, #iter = 956
# obj = -500.514690, rho = 0.877433
# nSV = 846, nBSV = 795
# *
# optimization finished, #iter = 331
# obj = -95.232733, rho = 1.249990
# nSV = 195, nBSV = 149
# *
# optimization finished, #iter = 400
# obj = -88.545010, rho = 0.430102
# nSV = 197, nBSV = 146
# ......................
# Warning: using -h 0 may be faster
# *....*
# optimization finished, #iter = 26189
# obj = -28766.681156, rho = 3.971292
# nSV = 34504, nBSV = 34214
# ..........
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 11895
# obj = -11341.987351, rho = -6.595948
# nSV = 14532, nBSV = 14373
# ..
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 2407
# obj = -1661.516767, rho = -5.210486
# nSV = 2554, nBSV = 2483
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2330
# obj = -1306.851463, rho = -4.563809
# nSV = 2099, nBSV = 2016
# .......
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 8835
# obj = -6331.399316, rho = -1.827064
# nSV = 9182, nBSV = 9013
# ...
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 5107
# obj = -1685.681673, rho = 1.213842
# nSV = 3056, nBSV = 2824
# ....
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 6154
# obj = -3406.579915, rho = 0.223395
# nSV = 5072, nBSV = 4858
# ...........
# Warning: using -h 0 may be faster
# *.*.*
# optimization finished, #iter = 12467
# obj = -12083.335626, rho = -8.776539
# nSV = 15176, nBSV = 15025
# ...
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4660
# obj = -3374.899382, rho = -7.976774
# nSV = 4829, nBSV = 4726
# ..
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 3342
# obj = -1971.580833, rho = -4.551991
# nSV = 3111, nBSV = 3012
# .......
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 9680
# obj = -6567.110376, rho = -1.180859
# nSV = 9762, nBSV = 9563
# ....
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 5989
# obj = -1761.433577, rho = 0.618221
# nSV = 3270, nBSV = 3011
# ....
# Warning: using -h 0 may be faster
# *..*.*
# optimization finished, #iter = 6758
# obj = -2713.199271, rho = -0.756631
# nSV = 4283, nBSV = 4023
# .....
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 6586
# obj = -6318.159161, rho = -4.000587
# nSV = 8091, nBSV = 8014
# ....
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 4873
# obj = -3745.451365, rho = -0.460311
# nSV = 5615, nBSV = 5521
# .............
# Warning: using -h 0 may be faster
# *..*.
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 16204
# obj = -13660.726650, rho = 7.353873
# nSV = 18882, nBSV = 18708
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2493
# obj = -649.113715, rho = 0.843818
# nSV = 1249, nBSV = 1106
# .
# Warning: using -h 0 may be faster
# **.*
# optimization finished, #iter = 1841
# obj = -784.364568, rho = 1.810863
# nSV = 1325, nBSV = 1234
# ..............
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 16022
# obj = -14805.085894, rho = -1.425804
# nSV = 21357, nBSV = 21248
# .......
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 8920
# obj = -7472.293933, rho = 7.713022
# nSV = 10340, nBSV = 10232
# *
# optimization finished, #iter = 817
# obj = -253.526993, rho = 1.327425
# nSV = 486, nBSV = 427
# *
# optimization finished, #iter = 443
# obj = -123.374265, rho = 0.854132
# nSV = 248, nBSV = 207
# ........
# Warning: using -h 0 may be faster
# *.
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 10931
# obj = -8472.702944, rho = 10.075386
# nSV = 11790, nBSV = 11664
# *.*
# optimization finished, #iter = 1339
# obj = -180.070941, rho = -0.081986
# nSV = 418, nBSV = 299
# *
# optimization finished, #iter = 648
# obj = -87.610181, rho = 0.409313
# nSV = 219, nBSV = 139
# .
# Warning: using -h 0 may be faster
# *.*
# optimization finished, #iter = 2048
# obj = -379.830621, rho = -0.291781
# nSV = 799, nBSV = 647
# .
# Warning: using -h 0 may be faster
# *
# optimization finished, #iter = 1419
# obj = -302.436352, rho = -0.019757
# nSV = 626, nBSV = 506
# .......
# Warning: using -h 0 may be faster
# *..*
# optimization finished, #iter = 9670
# obj = -6834.972531, rho = -1.196623
# nSV = 9663, nBSV = 9381
# Total nSV = 297904
# SVC(random_state=42, verbose=True)

# %%
# Prédictions sur les données de test
y_pred = svm_model.predict(X_test)

# %%
# Évaluation du modèle
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy * 100:.2f}%")
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 90.84%
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.57      0.51      0.54     10522
#            1       0.99      0.98      0.98     10689
#            2       0.98      0.95      0.97     10560
#            3       0.90      0.98      0.94     10418
#            4       0.84      0.90      0.87     10639
#            5       0.96      0.93      0.95     10527
#            6       0.95      0.97      0.96     10435
#            7       0.89      0.92      0.90     10718
#            9       1.00      1.00      1.00     10657
#           10       1.00      0.99      0.99     10392
#           11       0.99      1.00      1.00     10552
#           12       0.79      0.78      0.79     10463
#           13       0.81      0.76      0.78     10493
#           16       0.84      0.88      0.86     10534
#           17       0.93      0.95      0.94     10497
#           18       0.94      0.96      0.95     10490
#           19       0.94      0.89      0.91     10426
#           20       0.95      0.96      0.96      9379
#           24       0.97      0.96      0.96      9810
#
#     accuracy                           0.91    198201
#    macro avg       0.91      0.91      0.91    198201
# weighted avg       0.91      0.91      0.91    198201

# %% [markdown]
# Test du modèle

# %%
sample = df.sample(n=1)
y = sample['activityID']
x = sample.drop(columns=['timestamp', 'activityID'])

print(svm_model.predict(x))
print(pd.array(y))
# Out:
# [ 0 16  9 18  4  4 19 13  0 13]
# <NumpyExtensionArray>
# [20, 12, 9, 18, 4, 4, 19, 0, 0, 13]
# Length: 10, dtype: int64

# %%
import joblib
joblib.dump(svm_model, 'svm_model_last.joblib')
# Out:
# ['svm_model_last.joblib']
